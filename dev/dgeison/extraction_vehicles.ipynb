# %% [markdown]
# ### SWAPI
# Endpoints:
# * /vehicles: Retorna informações sobre os veículos presentes na saga Star Wars.
# * /species: Retorna informações sobre as espécies presentes na saga Star Wars.

# %%
### Importação de bibliotecas
import requests 
import pandas as pd

# %%
def extrair_dados(endpoint):
    """
    Extrai dados de um endpoint específico com paginação.

    Args:
        endpoint (str): O endpoint a ser consultado.

    Returns:
        list or None: Uma lista contendo os resultados extraídos do endpoint.
                      Retorna None em caso de erro na extração dos dados.

    Raises:
        requests.exceptions.RequestException: Exceção lançada em caso de erro na solicitação HTTP.
    """

    # Constrói a URL completa para o endpoint especificado
    url = f"https://swapi.dev/api/{endpoint}/"

    try:
        # Cria uma sessão em cada interação, permitindo que a conexão seja mantida aberta
        session = requests.Session()

        # Envia uma solicitação GET para a URL usando a biblioteca 'requests'
        response = session.get(url)

        # Verifica se a resposta tem um status code 200 (indicando uma resposta bem-sucedida)
        if response.status_code == 200:
            # Extrai os dados da resposta em formato JSON
            data = response.json()

            # Inicializa uma lista chamada 'results' com os resultados extraídos 
            results = data['results']

            # Verifica se há um link para a próxima página nos dados extraídos
            while data['next']:
                # Havendo próxima página, envia uma nova solicitação GET 
                response = session.get(data['next'])
                data = response.json()

                # Adiciona os dados da próxima página à lista 'results'
                results.extend(data['results'])

            # Retorna a lista completa de resultados extraídos
            return results
        else:
            # Se a resposta inicial não for bem-sucedida (status code diferente de 200),
            # exibe uma mensagem de erro indicando o endpoint e o status code da resposta
            print(f"Erro ao extrair dados do endpoint {endpoint}. Status code: {response.status_code}")

    except requests.exceptions.RequestException as e:
        # Trata exceções de solicitação HTTP, exibindo uma mensagem de erro
        raise requests.exceptions.RequestException(f"Erro na solicitação HTTP: {e}")

    # Retorna None para indicar que ocorreu um erro na extração dos dados
    return None

# %%
def extracao_vehicles():
    # Extração dos dados dos veículos (/vehicles)
    print('Iniciando extração dos dados do endpoint /vehicles...')
    dados_veiculos = extrair_dados('vehicles')
    if dados_veiculos:
        print("Dados dos veículos:")
        veiculos = []
        for veiculo in dados_veiculos:
            # Extrai os campos relevantes de cada veículo
            veiculos.append({
                "Nome": veiculo['name'],
                "Modelo": veiculo['model'],
                "Fabricante": veiculo['manufacturer'],
                "Custo em Créditos": veiculo['cost_in_credits'],
                "Comprimento": veiculo['length'],
                "Velocidade Máxima na Atmosfera": veiculo['max_atmosphering_speed'],
                "Tripulação": veiculo['crew'],
                "Passageiros": veiculo['passengers'],
                "Capacidade de Carga": veiculo['cargo_capacity'],
                "Consumíveis": veiculo['consumables'],
                "Classe do Veículo": veiculo['vehicle_class'],
                "Pilotos": veiculo['pilots'],
                "Filmes": veiculo['films'],
                "URL": veiculo['url'],
                "Criado": veiculo['created'],
                "Editado": veiculo['edited']

            })



        print('Extração de dados do endpoint /vehicles concluída!')
        # Cria um DataFrame com os dados dos veículos
        veiculos = pd.DataFrame(veiculos)
        print(veiculos)
        print("-----")

        # Exportar DataFrame para CSV
        veiculos.to_csv('veiculos.csv', index=False)
        print('veiculos.csv criado com sucesso!')

        return veiculos

# %%
def extracao_species():
    # Extração dos dados das naves espaciais (/species)
    print('Iniciando extração dos dados do endpoint /species...')
    dados_species = extrair_dados('species')
    if dados_species:
        print("Dados das naves espaciais:")
        species = []
        for specie in dados_species:
            # Extrai os campos relevantes de cada nave espacial
            species.append({
                "Nome": specie['name'],
                "Classificação": specie['classification'],
                "Designação": specie['designation'],
                "Altura Média": specie['average_height'],
                "Expectativa de Vida Média": specie['average_lifespan'],
                "Cores dos Olhos": specie['eye_colors'],
                "Cores do Cabelo": specie['hair_colors'],
                "Cores da Pele": specie['skin_colors'],
                "Idioma": specie['language'],
                "Planeta Natal": specie['homeworld'],
                "Personagens": specie['people'],
                "Filmes": specie['films'],
                "URL": specie['url'],
                "Criado": specie['created'],
                "Editado": specie['edited'],

            })


        print('Extração de dados do endpoint /species concluída!')
        # Cria um DataFrame com os dados das naves espaciais
        df_species = pd.DataFrame(species)
        print(df_species)
        print("-----")

        # Exportar DataFrame para CSV
        df_species.to_csv('species.csv', index=False)
        print('species.csv criado com sucesso!')

        return species

# %%
def main():
    extracao_vehicles()
    extracao_species()

# %%
if __name__ == "__main__":
    main()
# Out:
# Iniciando extração dos dados do endpoint /vehicles...
# Dados dos veículos:
# Extração de dados do endpoint /vehicles concluída!
#                               Nome                                    Modelo  \
# 0                     Sand Crawler                            Digger Crawler
# 1                   T-16 skyhopper                            T-16 skyhopper
# 2                 X-34 landspeeder                          X-34 landspeeder
# 3               TIE/LN starfighter            Twin Ion Engine/Ln Starfighter
# 4                      Snowspeeder                           t-47 airspeeder
# 5                       TIE bomber                             TIE/sa bomber
# 6                            AT-AT             All Terrain Armored Transport
# 7                            AT-ST               All Terrain Scout Transport
# 8      Storm IV Twin-Pod cloud car                         Storm IV Twin-Pod
# 9                       Sail barge                Modified Luxury Sail Barge
# 10           Bantha-II cargo skiff                                 Bantha-II
# 11              TIE/IN interceptor               Twin Ion Engine Interceptor
# 12           Imperial Speeder Bike                         74-Z speeder bike
# 13                   Vulture Droid           Vulture-class droid starfighter
# 14           Multi-Troop Transport                     Multi-Troop Transport
# 15            Armored Assault Tank                     Armoured Assault Tank
# 16  Single Trooper Aerial Platform            Single Trooper Aerial Platform
# 17            C-9979 landing craft                      C-9979 landing craft
# 18                 Tribubble bongo                           Tribubble bongo
# 19                    Sith speeder                        FC-20 speeder bike
# 20             Zephyr-G swoop bike                       Zephyr-G swoop bike
# 21      Koro-2 Exodrive airspeeder                Koro-2 Exodrive airspeeder
# 22                 XJ-6 airspeeder                           XJ-6 airspeeder
# 23                          LAAT/i  Low Altitude Assault Transport/infrantry
# 24                          LAAT/c    Low Altitude Assault Transport/carrier
# 25                           AT-TE             All Terrain Tactical Enforcer
# 26                            SPHA            Self-Propelled Heavy Artillery
# 27                Flitknot speeder                          Flitknot speeder
# 28              Neimoidian shuttle       Sheathipede-class transport shuttle
# 29           Geonosian starfighter          Nantex-class territorial defense
# 30     Tsmeu-6 personal wheel bike               Tsmeu-6 personal wheel bike
# 31           Emergency Firespeeder                  Fire suppression speeder
# 32               Droid tri-fighter                               tri-fighter
# 33           Oevvaor jet catamaran                     Oevvaor jet catamaran
# 34     Raddaugh Gnasp fluttercraft               Raddaugh Gnasp fluttercraft
# 35                Clone turbo tank                        HAVw A6 Juggernaut
# 36   Corporate Alliance tank droid     NR-N99 Persuader-class droid enforcer
# 37                   Droid gunship                         HMP droid gunship
# 38                           AT-RT               All Terrain Recon Transport
#
#                                            Fabricante Custo em Créditos  \
# 0                         Corellia Mining Corporation            150000
# 1                                   Incom Corporation             14500
# 2                                SoroSuub Corporation             10550
# 3                                Sienar Fleet Systems           unknown
# 4                                   Incom corporation           unknown
# 5                                Sienar Fleet Systems           unknown
# 6   Kuat Drive Yards, Imperial Department of Milit...           unknown
# 7   Kuat Drive Yards, Imperial Department of Milit...           unknown
# 8                                       Bespin Motors             75000
# 9        Ubrikkian Industries Custom Vehicle Division            285000
# 10                               Ubrikkian Industries              8000
# 11                               Sienar Fleet Systems           unknown
# 12                           Aratech Repulsor Company              8000
# 13     Haor Chall Engineering, Baktoid Armor Workshop           unknown
# 14                             Baktoid Armor Workshop            138000
# 15                             Baktoid Armor Workshop           unknown
# 16                             Baktoid Armor Workshop              2500
# 17                             Haor Chall Engineering            200000
# 18                  Otoh Gunga Bongameken Cooperative           unknown
# 19                                            Razalon              4000
# 20                        Mobquet Swoops and Speeders              5750
# 21          Desler Gizh Outworld Mobility Corporation           unknown
# 22                Narglatch AirTech prefabricated kit           unknown
# 23                          Rothana Heavy Engineering           unknown
# 24                          Rothana Heavy Engineering           unknown
# 25        Rothana Heavy Engineering, Kuat Drive Yards           unknown
# 26                          Rothana Heavy Engineering           unknown
# 27            Huppla Pasa Tisc Shipwrights Collective              8000
# 28                             Haor Chall Engineering           unknown
# 29            Huppla Pasa Tisc Shipwrights Collective           unknown
# 30               Z-Gomot Ternbuell Guppat Corporation             15000
# 31                                            unknown           unknown
# 32   Colla Designs, Phlac-Arphocc Automata Industries             20000
# 33                        Appazanna Engineering Works             12125
# 34                        Appazanna Engineering Works             14750
# 35                                   Kuat Drive Yards            350000
# 36                                       Techno Union             49000
# 37     Baktoid Fleet Ordnance, Haor Chall Engineering             60000
# 38                                   Kuat Drive Yards             40000
#
#    Comprimento Velocidade Máxima na Atmosfera Tripulação Passageiros  \
# 0        36.8                              30         46          30
# 1        10.4                            1200          1           1
# 2         3.4                             250          1           1
# 3          6.4                           1200          1           0
# 4          4.5                            650          2           0
# 5          7.8                            850          1           0
# 6           20                             60          5          40
# 7            2                             90          2           0
# 8            7                           1500          2           0
# 9           30                            100         26         500
# 10         9.5                            250          5          16
# 11         9.6                           1250          1           0
# 12           3                            360          1           1
# 13         3.5                           1200          0           0
# 14          31                             35          4         112
# 15        9.75                             55          4           6
# 16           2                            400          1           0
# 17         210                            587        140         284
# 18          15                             85          1           2
# 19         1.5                            180          1           0
# 20        3.68                            350          1           1
# 21         6.6                            800          1           1
# 22        6.23                            720          1           1
# 23        17.4                            620          6          30
# 24       28.82                            620          1           0
# 25        13.2                             60          6          36
# 26         140                             35         25          30
# 27           2                            634          1           0
# 28          20                            880          2           6
# 29         9.8                          20000          1           0
# 30         3.5                            330          1           1
# 31     unknown                        unknown          2     unknown
# 32         5.4                           1180          1           0
# 33        15.1                            420          2           2
# 34           7                            310          2           0
# 35        49.4                            160         20         300
# 36       10.96                            100          0           4
# 37        12.3                            820          0           0
# 38         3.2                             90          1           0
#
#    Capacidade de Carga      Consumíveis          Classe do Veículo  \
# 0                50000         2 months                    wheeled
# 1                   50                0              repulsorcraft
# 2                    5          unknown              repulsorcraft
# 3                   65           2 days                starfighter
# 4                   10             none                 airspeeder
# 5                 none           2 days     space/planetary bomber
# 6                 1000          unknown             assault walker
# 7                  200             none                     walker
# 8                   10            1 day              repulsorcraft
# 9              2000000  Live food tanks                 sail barge
# 10              135000            1 day  repulsorcraft cargo skiff
# 11                  75           2 days                starfighter
# 12                   4            1 day                    speeder
# 13                   0             none                starfighter
# 14               12000          unknown              repulsorcraft
# 15             unknown          unknown              repulsorcraft
# 16                none             none              repulsorcraft
# 17             1800000            1 day              landing craft
# 18                1600          unknown                  submarine
# 19                   2          unknown                    speeder
# 20                 200             none              repulsorcraft
# 21                  80          unknown                 airspeeder
# 22             unknown          unknown                 airspeeder
# 23                 170          unknown                    gunship
# 24               40000          unknown                    gunship
# 25               10000          21 days                     walker
# 26                 500           7 days                     walker
# 27             unknown          unknown                    speeder
# 28                1000           7 days                  transport
# 29             unknown          unknown                starfighter
# 30                  10             none             wheeled walker
# 31             unknown          unknown      fire suppression ship
# 32                   0             none          droid starfighter
# 33                  50           3 days                 airspeeder
# 34                  20             none                air speeder
# 35               30000          20 days             wheeled walker
# 36                none             none                 droid tank
# 37                   0             none                 airspeeder
# 38                  20            1 day                     walker
#
#                                               Pilotos  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [https://swapi.dev/api/people/1/, https://swap...
# 5                                                  []
# 6                                                  []
# 7                  [https://swapi.dev/api/people/13/]
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12  [https://swapi.dev/api/people/1/, https://swap...
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18  [https://swapi.dev/api/people/10/, https://swa...
# 19                 [https://swapi.dev/api/people/44/]
# 20                 [https://swapi.dev/api/people/11/]
# 21                 [https://swapi.dev/api/people/70/]
# 22                 [https://swapi.dev/api/people/11/]
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27                 [https://swapi.dev/api/people/67/]
# 28                                                 []
# 29                                                 []
# 30                 [https://swapi.dev/api/people/79/]
# 31                                                 []
# 32                                                 []
# 33                                                 []
# 34                                                 []
# 35                                                 []
# 36                                                 []
# 37                                                 []
# 38                                                 []
#
#                                                Filmes  \
# 0   [https://swapi.dev/api/films/1/, https://swapi...
# 
# 25  2014-12-20T21:30:21.728000Z
# 26  2014-12-20T21:30:21.731000Z
# 27  2014-12-20T21:30:21.735000Z
# 28  2014-12-20T21:30:21.739000Z
# 29  2014-12-20T21:30:21.742000Z
# 30  2014-12-20T21:30:21.745000Z
# 31  2014-12-20T21:30:21.749000Z
# 32  2014-12-20T21:30:21.752000Z
# 33  2014-12-20T21:30:21.756000Z
# 34  2014-12-20T21:30:21.759000Z
# 35  2014-12-20T21:30:21.762000Z
# 36  2014-12-20T21:30:21.765000Z
# 37  2014-12-20T21:30:21.768000Z
# 38  2014-12-20T21:30:21.772000Z
# -----
# veiculos.csv criado com sucesso!
# Iniciando extração dos dados do endpoint /species...
# Dados das naves espaciais:
# Extração de dados do endpoint /species concluída!
#               Nome Classificação Designação Altura Média  \
# 0            Human        mammal   sentient          180
# 1            Droid    artificial   sentient          n/a
# 2           Wookie        mammal   sentient          210
# 3           Rodian      sentient  reptilian          170
# 4             Hutt     gastropod   sentient          300
# 5   Yoda's species        mammal   sentient           66
# 6       Trandoshan       reptile   sentient          200
# 7     Mon Calamari     amphibian   sentient          160
# 8             Ewok        mammal   sentient          100
# 9        Sullustan        mammal   sentient          180
# 10       Neimodian       unknown   sentient          180
# 11          Gungan     amphibian   sentient          190
# 12       Toydarian        mammal   sentient          120
# 13             Dug        mammal   sentient          100
# 14         Twi'lek       mammals   sentient          200
# 15          Aleena       reptile   sentient           80
# 16      Vulptereen       unknown   sentient          100
# 17           Xexto       unknown   sentient          125
# 18           Toong       unknown   sentient          200
# 19          Cerean        mammal   sentient          200
# 20        Nautolan     amphibian   sentient          180
# 21          Zabrak        mammal   sentient          180
# 22      Tholothian        mammal   sentient      unknown
# 23        Iktotchi       unknown   sentient          180
# 24        Quermian        mammal   sentient          240
# 25         Kel Dor       unknown   sentient          180
# 26        Chagrian     amphibian   sentient          190
# 27       Geonosian     insectoid   sentient          178
# 28        Mirialan        mammal   sentient          180
# 29        Clawdite     reptilian   sentient          180
# 30        Besalisk     amphibian   sentient          178
# 31        Kaminoan     amphibian   sentient          220
# 32         Skakoan        mammal   sentient      unknown
# 33            Muun        mammal   sentient          190
# 34         Togruta        mammal   sentient          180
# 35         Kaleesh       reptile   sentient          170
# 36          Pau'an        mammal   sentient          190
#
#    Expectativa de Vida Média                          Cores dos Olhos  \
# 0                        120   brown, blue, green, hazel, grey, amber
# 1                 indefinite                                      n/a
# 2                        400  blue, green, yellow, brown, golden, red
# 3                    unknown                                    black
# 4                       1000                              yellow, red
# 5                        900                     brown, green, yellow
# 6                    unknown                           yellow, orange
# 7                    unknown                                   yellow
# 8                    unknown                            orange, brown
# 9                    unknown                                    black
# 10                   unknown                                red, pink
# 11                   unknown                                   orange
# 12                        91                                   yellow
# 13                   unknown                             yellow, blue
# 14                   unknown                blue, brown, orange, pink
# 15                        79                                  unknown
# 16                   unknown                                   yellow
# 17                   unknown                                    black
# 18                   unknown                                   orange
# 19                   unknown                                    hazel
# 20                        70                                    black
# 21                   unknown                            brown, orange
# 22                   unknown                             blue, indigo
# 23                   unknown                                   orange
# 24                        86                                   yellow
# 25                        70                            black, silver
# 26                   unknown                                     blue
# 27                   unknown                             green, hazel
# 28                   unknown  blue, green, red, yellow, brown, orange
# 29                        70                                   yellow
# 30                        75                                   yellow
# 31                        80                                    black
# 32                   unknown                                  unknown
# 33                       100                                    black
# 34                        94  red, orange, yellow, green, blue, black
# 35                        80                                   yellow
# 36                       700                                    black
#
#               Cores do Cabelo                                   Cores da Pele  \
# 0   blonde, brown, black, red               caucasian, black, asian, hispanic
# 1                         n/a                                             n/a
# 2                black, brown                                            gray
# 3                         n/a                                     green, blue
# 4                         n/a                               green, brown, tan
# 5                brown, white                                   green, yellow
# 6                        none                                    brown, green
# 7                        none                       red, blue, brown, magenta
# 8         white, brown, black                                           brown
# 9                        none                                            pale
# 10                       none                                     grey, green
# 11                       none                                    brown, green
# 12                       none                               blue, green, grey
# 13                       none                        brown, purple, grey, red
# 14                       none  orange, yellow, blue, green, pink, purple, tan
# 15                       none                                      blue, gray
# 16                       none                                            grey
# 17                       none                            grey, yellow, purple
# 18                       none                             grey, green, yellow
# 19   red, blond, black, white                                       pale pink
# 20                       none                         green, blue, brown, red
# 21                      black                pale, brown, red, orange, yellow
# 22                    unknown                                            dark
# 23                       none                                            pink
# 24                       none                                           white
# 25                       none                              peach, orange, red
# 26                       none                                            blue
# 27                       none                                    green, brown
# 28               black, brown                                   yellow, green
# 29                       none                                   green, yellow
# 30                       none                                           brown
# 31                       none                                      grey, blue
# 32                       none                                     grey, green
# 33                       none                                     grey, white
# 34                       none         red, white, orange, yellow, green, blue
# 35                       none                              brown, orange, tan
# 36                       none                                            grey
#
#             Idioma                      Planeta Natal  \
# 0   Galactic Basic   https://swapi.dev/api/planets/9/
# 1              n/a                               None
# 2       Shyriiwook  https://swapi.dev/api/planets/14/
# 3    Galatic Basic  https://swapi.dev/api/planets/23/
# 4          Huttese  https://swapi.dev/api/planets/24/
# 5   Galactic basic  https://swapi.dev/api/planets/28/
# 6             Dosh  https://swapi.dev/api/planets/29/
# 7   Mon Calamarian  https://swapi.dev/api/planets/31/
# 8          Ewokese   https://swapi.dev/api/planets/7/
# 9        Sullutese  https://swapi.dev/api/planets/33/
# 10       Neimoidia  https://swapi.dev/api/planets/18/
# 11    Gungan basic   https://swapi.dev/api/planets/8/
# 12       Toydarian  https://swapi.dev/api/planets/34/
# 13          Dugese  https://swapi.dev/api/planets/35/
# 14        Twi'leki  https://swapi.dev/api/planets/37/
# 15          Aleena  https://swapi.dev/api/planets/38/
# 16      vulpterish  https://swapi.dev/api/planets/39/
# 17         Xextese  https://swapi.dev/api/planets/40/
# 18          Tundan  https://swapi.dev/api/planets/41/
# 19          Cerean  https://swapi.dev/api/planets/43/
# 20         Nautila  https://swapi.dev/api/planets/44/
# 21         Zabraki  https://swapi.dev/api/planets/45/
# 22         unknown  https://swapi.dev/api/planets/46/
# 23      Iktotchese  https://swapi.dev/api/planets/47/
# 24        Quermian  https://swapi.dev/api/planets/48/
# 25         Kel Dor  https://swapi.dev/api/planets/49/
# 26         Chagria  https://swapi.dev/api/planets/50/
# 27       Geonosian  https://swapi.dev/api/planets/11/
# 28        Mirialan  https://swapi.dev/api/planets/51/
# 29        Clawdite  https://swapi.dev/api/planets/54/
# 30        besalisk  https://swapi.dev/api/planets/55/
# 31        Kaminoan  https://swapi.dev/api/planets/10/
# 32         Skakoan  https://swapi.dev/api/planets/56/
# 33            Muun  https://swapi.dev/api/planets/57/
# 34         Togruti  https://swapi.dev/api/planets/58/
# 35         Kaleesh  https://swapi.dev/api/planets/59/
# 36         Utapese  https://swapi.dev/api/planets/12/
#
#                                           Personagens  \
# 0   [https://swapi.dev/api/people/66/, https://swa...
# 1   [https://swapi.dev/api/people/2/, https://swap...
# 2   [https://swapi.dev/api/people/13/, https://swa...
# 3                  [https://swapi.dev/api/people/15/]
# 4                  [https://swapi.dev/api/people/16/]
# 5                  [https://swapi.dev/api/people/20/]
# 6                  [https://swapi.dev/api/people/24/]
# 7                  [https://swapi.dev/api/people/27/]
# 8                  [https://swapi.dev/api/people/30/]
# 9                  [https://swapi.dev/api/people/31/]
# 10                 [https://swapi.dev/api/people/33/]
# 11  [https://swapi.dev/api/people/36/, https://swa...
# 12                 [https://swapi.dev/api/people/40/]
# 13                 [https://swapi.dev/api/people/41/]
# 14  [https://swapi.dev/api/people/45/, https://swa...
# 15                 [https://swapi.dev/api/people/47/]
# 16                 [https://swapi.dev/api/people/48/]
# 17                 [https://swapi.dev/api/people/49/]
# 18                 [https://swapi.dev/api/people/50/]
# 19                 [https://swapi.dev/api/people/52/]
# 20                 [https://swapi.dev/api/people/53/]
# 21  [https://swapi.dev/api/people/44/, https://swa...
# 22                 [https://swapi.dev/api/people/55/]
# 23                 [https://swapi.dev/api/people/56/]
# 24                 [https://swapi.dev/api/people/57/]
# 25                 [https://swapi.dev/api/people/58/]
# 26                 [https://swapi.dev/api/people/59/]
# 27                 [https://swapi.dev/api/people/63/]
# 28  [https://swapi.dev/api/people/64/, https://swa...
# 29                 [https://swapi.dev/api/people/70/]
# 30                 [https://swapi.dev/api/people/71/]
# 31  [https://swapi.dev/api/people/72/, https://swa...
# 32                 [https://swapi.dev/api/people/76/]
# 33                 [https://swapi.dev/api/people/77/]
# 34                 [https://swapi.dev/api/people/78/]
# 35                 [https://swapi.dev/api/people/79/]
# 36                 [https://swapi.dev/api/people/83/]
#
#                                                Filmes  \
# 0   [https://swapi.dev/api/films/1/, https://swapi...
# 1   [https://swapi.dev/api/films/1/, https://swapi...
# 2   [https://swapi.dev/api/films/1/, https://swapi...
# 3                    [https://swapi.dev/api/films/1/]
# 4   [https://swapi.dev/api/films/1/, https://swapi...
